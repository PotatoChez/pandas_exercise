# %%
import numpy as np
import pandas as pd

dates = pd.date_range("20130101", periods=6)


df = pd.DataFrame(np.random.randn(6, 4), index=dates, columns=list("ABCD"))



print("testing")
# Out:
# testing

# %%
df
# Out:
#                    A         B         C         D
# 2013-01-01 -0.407271  1.790976 -1.545913 -0.100500
# 2013-01-02 -0.832864 -0.048298  0.893581  0.551728
# 2013-01-03  1.002104 -0.032078  0.604612 -0.779859
# 2013-01-04 -0.555548  1.175007  0.367957  2.262029
# 2013-01-05  0.502227  2.996663 -2.090583 -0.639816
# 2013-01-06  0.226961 -1.212173 -1.503998 -0.725883

# %%
df.plot()
# Out:
# <Axes: >

# %%
import warnings
warnings.filterwarnings('ignore')
